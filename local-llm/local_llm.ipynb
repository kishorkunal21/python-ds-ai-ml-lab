# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv
import os

load_dotenv()
KEY = os.getenv("GEMMA_KEY")

llm = ChatGoogleGenerativeAI(
    model="gemma-4-31b-it", #"gemma-4-26b-a4b-it",          # or "gemma-4-31b-it"
    google_api_key=KEY,
    temperature=0.7
)

response  = llm.invoke("give 1 line answer - what you can do?")

print(response.content)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'thinking', 'thinking': '*   Input: "give 1 line answer - what you can do?"\n    *   Constraint: 1 line answer.\n    *   Goal: Explain capabilities.\n\n    *   I am an AI.\n    *   I process and generate text.\n    *   I answer questions, write code, summarize, translate, etc.\n\n    *   *Draft 1:* I can process and generate text to help you with answering questions, writing, coding, and analyzing data. (Too long?)\n    *   *Draft 2:* I can answer questions, write content, code, translate languages, and assist with various cognitive tasks. (Better)\n    *   *Draft 3:* I can process information to answer questions, write text, solve problems, and assist with a wide range of tasks. (Good)\n    *   *Draft 4 (Concise):* I can process and generate text to answer questions, write content, code, and assist with various tasks.\n\n    "I can process and generate text to answer questions, write content, code, and assist with various tasks."'}, {'type': 'text', 'text': 'I can process and generate text to answer questions, write content, code, and assist with various tasks.'}]
